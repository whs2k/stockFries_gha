# %%
import pandas as pd
import datetime

# %%
df_to_tweet = pd.read_csv('df_company_info2.csv')
df_to_tweet['twitter'] = df_to_tweet['twitter'].astype(str)
df_to_tweet = df_to_tweet[(df_to_tweet.put_value>0) & 
                           (~df_to_tweet.twitter.str.contains(' ')) & 
                         (~(df_to_tweet.twitter=='nan'))].reset_index()
df_to_tweet.columns

'''for column_name in df_to_tweet.columns:
    if column_name in any(['Unamed']) :
        drop[column_name]
        df.drop(['''

print(df_to_tweet.columns)
bad_list_jr = ['index', 'Unnamed: 0.9', 'Unnamed: 0.8', 'Unnamed: 0.7', 'Unnamed: 0.6',
       'Unnamed: 0.5', 'Unnamed: 0.4', 'Unnamed: 0.3', 'Unnamed: 0.2',
       'Unnamed: 0.1', 'Unnamed: 0']
df_to_tweet.drop(bad_list_jr, axis=1, inplace=True)
df_to_tweet.sort_values('twitter').reset_index().tail()

#bad_list = ['index', 'Unnamed: 0.5', 'Unnamed: 0.4', 'Unnamed: 0.3', 'Unnamed: 0.2',
#       'Unnamed: 0.1', 'Unnamed: 0','put_value', 'hedge_funds_putting']
# Out:
# Index(['index', 'Unnamed: 0.9', 'Unnamed: 0.8', 'Unnamed: 0.7', 'Unnamed: 0.6',
#        'Unnamed: 0.5', 'Unnamed: 0.4', 'Unnamed: 0.3', 'Unnamed: 0.2',
#        'Unnamed: 0.1', 'Unnamed: 0', 'name', 'cusip', 'twitter', 'put_value',
#        'hedge_funds_putting'],
#       dtype='object')
#      index                       name      cusip  \
# 428    331           VANECK ETF TRUST  92189F205
# 429    379           VANECK ETF TRUST  92189F643
# 430     74                 VMWARE INC  928563402
# 431    108  WARNER BROS DISCOVERY INC  934423104
# 432    146                WORKDAY INC  98138H101
#
#                                                twitter    put_value  \
# 428                                          vaneck_us     216381.0
# 429                                          vaneck_us      53088.0
# 430  vmwarenews.</div></div></div></div></div></div...  322904608.0
# 431                                                wbd  209413944.0
# 432                                    workdaymagazine  151555190.0
#
#                                    hedge_funds_putting
# 428                           ['CITADEL ADVISORS LLC']
# 429                           ['CITADEL ADVISORS LLC']
# 430                           ['CITADEL ADVISORS LLC']
# 431  ['CAPITAL FUND MANAGEMENT', 'CITADEL ADVISORS ...
# 432  ['CAPITAL FUND MANAGEMENT', 'CITADEL ADVISORS ...

# %%
#df_backup = pd.read_csv('df_company_info2_backup.csv')
#df_backup.sort_values('twitter').reset_index().tail()

#bad_list = ['put_value', 'hedge_funds_putting']
#df_backup_new = df_to_tweet.drop(bad_list, axis=1)
#df_backup_new.tail()
#df_backup_new.to_csv('df_company_info2_backup.csv', index=False)
#df_backup_new.tail()
# Out:
#                             name      cusip       twitter
# 428                    ADEIA INC  00676P107     adeia_inc
# 429  ADVERUM BIOTECHNOLOGIES INC  00773U108    adverumbio
# 430                 AC IMMUNE SA  H00263105  AC_Immune_SA
# 431   AEGLEA BIOTHERAPEUTICS INC  00773J202     aegleabio
# 432       A K A BRANDS HLDG CORP  00152K101    aka_brands

# %%
#https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/main/Manage-Tweets/create_tweet.py
from requests_oauthlib import OAuth1Session
import os
import json

def send_tweet(tweet_text, consumer_key_,consumer_secret_,access_token_,access_token_secret):

    # In your terminal please set your environment variables by running the following lines of code.
    # export 'CONSUMER_KEY'='<your_consumer_key>'
    # export 'CONSUMER_SECRET'='<your_consumer_secret>'

    consumer_key = consumer_key_#os.environ.get("CONSUMER_KEY")
    consumer_secret = consumer_secret_#os.environ.get("CONSUMER_SECRET")

    # Be sure to add replace the text of the with the text you wish to Tweet. You can also add parameters to post polls, quote Tweets, Tweet with reply settings, and Tweet to Super Followers in addition to other features.
    payload = {"text": tweet_text}

    access_token = access_token_#oauth_tokens["oauth_token"]
    access_token_secret = access_token_secret#oauth_tokens["oauth_token_secret"]

    # Making the request
    response = oauth.post(
        "https://api.twitter.com/2/tweets",
        json=payload,
    )

    if response.status_code != 201:
        raise Exception(
            "Request returned an error: {} {}".format(response.status_code, response.text)
        )

    print("Response code: {}".format(response.status_code))

    # Saving the response as JSON
    json_response = response.json()
    print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
today = datetime.datetime.today().strftime('%Y-%m-%d')
def safe_to_tweet_guardrail(df_, twitter_handle_to_test):        
    print(df_[df_.most_recent_tweet_date = twitter_handle_to_test] - today).days
    if days_between > 90 &:
        return True
    else:
        return False

# %%
if df_.twitter_handle_to_test in df.columns:
    print('False')
df_to_tweet['most_recent_tweet']
